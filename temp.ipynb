# %%
from fastapi import FastAPI
from fastapi.middleware.cors import CORSMiddleware
from pydantic import BaseModel
import requests
import os
from dotenv import load_dotenv

TELEGRAM_BOT_TOKEN = "8021458974:AAH_U6vWbr877Cv669Ig88MFqWVUWZtf5Mk"
TELEGRAM_CHAT_ID = "5609562789"

def send_telegram_message(message):
    url = f"https://api.telegram.org/bot{TELEGRAM_BOT_TOKEN}/sendMessage"
    payload = {
        "chat_id": TELEGRAM_CHAT_ID,
        "text": message
    }
    response = requests.post(url, json=payload)
    return response.json()

send_telegram_message("Hello From VScode")
# Out:
# {'ok': True,
#  'result': {'message_id': 1353,
#   'from': {'id': 8021458974,
#    'is_bot': True,
#    'first_name': 'Trading Signals',
#    'username': 'Trading_signal_alerts_bot'},
#   'chat': {'id': 5609562789,
#    'first_name': 'Hardik',
#    'username': 'Hardik_GenOne',
#    'type': 'private'},
#   'date': 1767290325,
#   'text': 'Hello From VScode'}}
